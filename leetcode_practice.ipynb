# %% [markdown]
# # LeetCode Practice Notebook
#
# A Jupyter notebook for practicing LeetCode problems.
#
# ## How to Use
# 1. Copy a problem template cell below
# 2. Fill in the problem details and your solution
# 3. Run the test cases to verify your solution

# %% [markdown]
# ---
# ## Problem Template
#
# **Problem Number:** [Number]
#
# **Problem Title:** [Title]
#
# **Difficulty:** Easy / Medium / Hard
#
# **Link:** [LeetCode URL]
#
# **Description:**
# [Problem description here]

# %%
# Solution Template
class Solution:
    def solution_method(self, input_param):
        """
        Your solution here.
        
        Args:
            input_param: Description of input
            
        Returns:
            Description of output
        """
        pass

# %%
# Test Cases Template
def test_solution():
    sol = Solution()
    
    # Test Case 1
    # assert sol.solution_method(input1) == expected1
    
    # Test Case 2
    # assert sol.solution_method(input2) == expected2
    
    print("All test cases passed!")

# Uncomment to run tests
# test_solution()

# %% [markdown]
# ---
# ## Example: Two Sum (Problem #1)
#
# **Problem Number:** 1
#
# **Problem Title:** Two Sum
#
# **Difficulty:** Easy
#
# **Link:** https://leetcode.com/problems/two-sum/
#
# **Description:**
# Given an array of integers `nums` and an integer `target`, return indices of the two numbers such that they add up to `target`.
#
# You may assume that each input would have exactly one solution, and you may not use the same element twice.

# %%
from typing import List

class TwoSumSolution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        """
        Find two numbers that add up to target.
        
        Args:
            nums: List of integers
            target: Target sum
            
        Returns:
            List of two indices
        """
        seen = {}
        for i, num in enumerate(nums):
            complement = target - num
            if complement in seen:
                return [seen[complement], i]
            seen[num] = i
        return []

# %%
# Test Cases for Two Sum
def test_two_sum():
    sol = TwoSumSolution()
    
    # Test Case 1
    assert sol.twoSum([2, 7, 11, 15], 9) == [0, 1]
    
    # Test Case 2
    assert sol.twoSum([3, 2, 4], 6) == [1, 2]
    
    # Test Case 3
    assert sol.twoSum([3, 3], 6) == [0, 1]
    
    print("All test cases passed!")

test_two_sum()
